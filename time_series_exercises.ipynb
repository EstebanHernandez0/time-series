# %%
import requests
import pandas as pd
import os

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Using the code from the lesson as a guide and the REST API from https://swapi.dev/ as we did in the lesson, create a dataframe named people that has all of the data for people.

# %%
url= 'https://swapi.dev/api/people/'

# %%
response = requests.get(url)
data=response.json()

# %%
data.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
character= pd.DataFrame(data['results'])
character
# Out:
#                  name height mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker    172   77          blond         fair       blue
# 1               C-3PO    167   75            n/a         gold     yellow
# 2               R2-D2     96   32            n/a  white, blue        red
# 3         Darth Vader    202  136           none        white     yellow
# 4         Leia Organa    150   49          brown        light      brown
# 5           Owen Lars    178  120    brown, grey        light       blue
# 6  Beru Whitesun lars    165   75          brown        light       blue
# 7               R5-D4     97   32            n/a   white, red        red
# 8   Biggs Darklighter    183   84          black        light      brown
# 9      Obi-Wan Kenobi    182   77  auburn, white         fair  blue-gray
#
#   birth_year  gender                          homeworld  \
# 0      19BBY    male   https://swapi.dev/api/planets/1/
# ...

# %% [markdown]
# ## Do the same thing, but for planets.

# %%
url= 'https://swapi.dev/api/planets/'

# %%
res= requests.get(url)
planets= res.json()
data.keys()
# Out:
# dict_keys(['count', 'next', 'previous', 'results'])

# %%
planet= pd.DataFrame(planets['results'])
planet
# Out:
#         name rotation_period orbital_period diameter              climate  \
# 0   Tatooine              23            304    10465                 arid
# 1   Alderaan              24            364    12500            temperate
# 2   Yavin IV              24           4818    10200  temperate, tropical
# 3       Hoth              23            549     7200               frozen
# 4    Dagobah              23            341     8900                murky
# 5     Bespin              12           5110   118000            temperate
# 6      Endor              18            402     4900            temperate
# 7      Naboo              26            312    12120            temperate
# 8  Coruscant              24            368    12240            temperate
# 9     Kamino              27            463    19720            temperate
#
#                                   gravity  \
# 0                              1 standard
# 1                              1 standard
# ...

# %% [markdown]
# ## Extract the data for starships.

# %%
url= 'https://swapi.dev/api/starships/'
response= requests.get(url)
star= response.json()

# %%
starship= pd.DataFrame(star['results'])
starship
# Out:
#                            name                            model  \
# 0                 CR90 corvette                    CR90 corvette
# 1                Star Destroyer  Imperial I-class Star Destroyer
# 2  Sentinel-class landing craft     Sentinel-class landing craft
# 3                    Death Star      DS-1 Orbital Battle Station
# 4             Millennium Falcon          YT-1300 light freighter
# 5                        Y-wing                       BTL Y-wing
# 6                        X-wing                      T-65 X-wing
# 7               TIE Advanced x1      Twin Ion Engine Advanced x1
# 8                      Executor  Executor-class star dreadnought
# 9               Rebel transport           GR-75 medium transport
#
#                                         manufacturer cost_in_credits  length  \
# 0                  Corellian Engineering Corporation         3500000     150
# 1                                   Kuat Drive Yards       150000000   1,600
# ...

# %% [markdown]
# ## Save the data in your files to local csv files so that it will be faster to access in the future.

# %%
character.to_csv('character_csv', index= False)
planet.to_csv('planet_csv', index= False)
starship.to_csv('starship_csv', index= False)

# %% [markdown]
# ## Combine the data from your three separate dataframes into one large dataframe.

# %%
ch= pd.read_csv('character_csv')
pl= pd.read_csv('planet_csv')
st= pd.read_csv('starship_csv')

# %%
pd.concat([pl, ch, st], ignore_index=True)
# Out:
#                             name  rotation_period  orbital_period  diameter  \
# 0                       Tatooine             23.0           304.0   10465.0
# 1                       Alderaan             24.0           364.0   12500.0
# 2                       Yavin IV             24.0          4818.0   10200.0
# 3                           Hoth             23.0           549.0    7200.0
# 4                        Dagobah             23.0           341.0    8900.0
# 5                         Bespin             12.0          5110.0  118000.0
# 6                          Endor             18.0           402.0    4900.0
# 7                          Naboo             26.0           312.0   12120.0
# 8                      Coruscant             24.0           368.0   12240.0
# 9                         Kamino             27.0           463.0   19720.0
# 10                Luke Skywalker              NaN             NaN       NaN
# ...

# %% [markdown]
# ## Acquire the Open Power Systems Data for Germany, which has been rapidly expanding its renewable energy production in recent years. The data set includes country-wide totals of electricity consumption, wind power production, and solar power production for 2006-2017. You can get the data here: https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv

# %%
df= pd.read_csv('https://raw.githubusercontent.com/jenfly/opsd/master/opsd_germany_daily.csv')
df.to_csv('OPSD.csv', index=False)

# %% [markdown]
# ## Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions in the acquire.py file and be able to re-run the functions and get the same data.

# %%
def get_characters():
    if os.path.isfile('character_csv'):
        
        return pd.read_csv('character_csv')

    else:
        url= 'https://swapi.dev/api/people/'
        res= requests.get(url)
        data= res.json()
        df= pd.DataFrame(data['results'])
        return df
get_characters()
# Out:
#                  name  height  mass     hair_color   skin_color  eye_color  \
# 0      Luke Skywalker     172    77          blond         fair       blue
# 1               C-3PO     167    75            NaN         gold     yellow
# 2               R2-D2      96    32            NaN  white, blue        red
# 3         Darth Vader     202   136           none        white     yellow
# 4         Leia Organa     150    49          brown        light      brown
# 5           Owen Lars     178   120    brown, grey        light       blue
# 6  Beru Whitesun lars     165    75          brown        light       blue
# 7               R5-D4      97    32            NaN   white, red        red
# 8   Biggs Darklighter     183    84          black        light      brown
# 9      Obi-Wan Kenobi     182    77  auburn, white         fair  blue-gray
#
#   birth_year  gender                          homeworld  \
# 0      19BBY    male   https://swapi.dev/api/planets/1/
# ...

# %%
def get_starchips():
    if os.path.isfile('character_csv'):
        
        return pd.read_csv('character_csv')

    else:
        url= 'https://swapi.dev/api/people/'
        res= requests.get(url)
        data= res.json()
        df= pd.DataFrame(data['results'])
        return df
